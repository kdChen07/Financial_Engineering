# %% [markdown]
# <a href="https://colab.research.google.com/github/kdChen07/Financial_Engineering/blob/main/MLE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy as sp
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('BDI.xlsx')      # 文件读取要确定好位置
df.insert(1, '天数', range(1,len(df)+1))

# %%
df
# Out:
#             日期   天数   BDI
# 0   2020-03-30    1   548
# 1   2020-03-31    2   626
# 2   2020-04-01    3   624
# 3   2020-04-02    4   624
# 4   2020-04-03    5   616
# ..         ...  ...   ...
# 496 2022-03-23  497  2575
# 497 2022-03-24  498  2567
# 498 2022-03-25  499  2544
# 499 2022-03-28  500  2484
# 500 2022-03-29  501  2417
#
# [501 rows x 3 columns]

# %%
def MLE(df):
    u,q = sp.symbols('u q')     # u,q表示均值和方差
    t = df['天数']
    s = df['BDI']
    s0 = df.loc[450,'BDI']
    F = 1
    for i in range(1,len(df)):
        f = sp.exp( -(np.log10(s[i]) - np.log10(s0) - (u - 0.5* q**2)* t[i])**2 / (2* q**2 * t[i]) ) / (np.sqrt(2 * np.pi * t[i]) * q * s[i])
        F = F * f
    logF = sp.expand_log(sp.log(F))
    logF_u = sp.diff(logF,u)
    logF_q = sp.diff(logF,q)
    result = sp.solve([logF_u, logF_q],[u, q])
    return result
result = MLE(df)
print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-e84316453151> in <module>()
#      13     result = sp.solve([logF_u, logF_q],[u, q])
#      14     return result
# ---> 15 result = MLE(df)
#      16 print(result)
#
# <ipython-input-22-e84316453151> in MLE(df)
#       6     F = 1
#       7     for i in range(1,len(a_df)):
# ...
