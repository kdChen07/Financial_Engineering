# %% [markdown]
# <a href="https://colab.research.google.com/github/kdChen07/Financial_Engineering/blob/main/Untitled34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
N1=1000000
N2=250
S=100
a=np.ones(N1)
S0=S*a
T=365/365
t_delta=T/N2
mu=0.1
r=0.1
sigma=0.3
K=100

# %%
St=np.zeros((N1,N2))
St[:,0]=S0
St
# Out:
# array([[100.,   0.,   0., ...,   0.,   0.,   0.],
#        [100.,   0.,   0., ...,   0.,   0.,   0.],
#        [100.,   0.,   0., ...,   0.,   0.,   0.],
#        ...,
#        [100.,   0.,   0., ...,   0.,   0.,   0.],
#        [100.,   0.,   0., ...,   0.,   0.,   0.],
#        [100.,   0.,   0., ...,   0.,   0.,   0.]])

# %%
for i in range(0,N1):
  Epsilon = np.random.normal(0, 1, N2)
  for t in range(1,N2):
    St[i,t]=St[i,t-1]+(mu+r*St[i,t-1])*t_delta+sigma*math.sqrt(St[i,t-1])*math.sqrt(t_delta)*Epsilon[t]

# %%
St
# Out:
# array([[100.        ,  99.90947498,  99.79648588, ..., 109.52820553,
#         109.6324448 , 109.7950176 ],
#        [100.        , 100.05356376, 100.17148622, ..., 117.66512203,
#         117.85252748, 117.93606413],
#        [100.        , 100.08027255, 100.10272527, ..., 110.09147678,
#         110.04453136, 110.10392609],
#        ...,
#        [100.        ,  99.81879297, 100.06170608, ..., 104.84635033,
#         104.85475992, 104.95746505],
#        [100.        , 100.06354879, 100.26643329, ..., 111.86528193,
#         112.11378411, 112.14450072],
#        [100.        , 100.26216475, 100.35345082, ..., 106.48662392,
#         106.74584738, 106.91098488]])

# %%
x = np.arange(0,N2,1)
y = St

# %%
plt.subplots(figsize=(16,9),dpi=100)
for i in range(0,N2):
  plt.plot(x, y[i,:])
  plt.title('Monte Carlo')
  plt.xlabel('Step')
  plt.ylabel('Price')
