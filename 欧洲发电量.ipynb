# %% [markdown]
# <a href="https://colab.research.google.com/github/kdChen07/Financial_Engineering/blob/main/%E6%AC%A7%E6%B4%B2%E5%8F%91%E7%94%B5%E9%87%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("data123.csv")
data
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0,1,2,3,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           Country    Time                     Balance  \
# 0       Australia  Sep-22  Net Electricity Production
# 1       Australia  Sep-22  Net Electricity Production
# 2       Australia  Sep-22  Net Electricity Production
# 3       Australia  Sep-22  Net Electricity Production
# 4       Australia  Sep-22  Net Electricity Production
# ...           ...     ...                         ...
# 927956        NaN     NaN                         NaN
# 927957        NaN     NaN                         NaN
# 927958        NaN     NaN                         NaN
# 927959        NaN     NaN                         NaN
# 927960        NaN     NaN                         NaN
#
#                                   Product       Value Unit
# ...

# %%
data=data.dropna()
data
# Out:
#         Country    Time                     Balance  \
# 0     Australia  Sep-22  Net Electricity Production
# 1     Australia  Sep-22  Net Electricity Production
# 2     Australia  Sep-22  Net Electricity Production
# 3     Australia  Sep-22  Net Electricity Production
# 4     Australia  Sep-22  Net Electricity Production
# ...         ...     ...                         ...
# 5712     Serbia  Jan-22  Net Electricity Production
# 5713     Serbia  Jan-22  Net Electricity Production
# 5714     Serbia  Jan-22  Net Electricity Production
# 5715     Serbia  Jan-22  Net Electricity Production
# 5716     Serbia  Jan-22  Net Electricity Production
#
#                                          Product       Value Unit
# 0                                    Electricity  21161.5036  GWh
# 1                        Total Combustible Fuels  13777.8878  GWh
# 2              Coal, Peat and Manufactured Gases   9631.9664  GWh
# 3                     Oil and Petroleum Products    333.9555  GWh
# ...

# %%
result=[]

# %%
a=data.values

# %%
Europe_name="Norway","Finland","Sweden","Iceland","Denmark","Faroe Islands","Estonia","Latvia","Lithuania","Moldova","Belarus","Russia","Ukraine","Poland","Czech","Slovakia","Hungary","Germany","Austria","Switzerland","Liechtenstein","United Kingdom","Ireland","Netherlands","Belgium","Luxembourg","France","Monaco","Romania","Bulgaria","Serbia","Macedonia","Slovenia","Croatia","Montenegro","Bosnia and Herzegovina","Albania","Greece","Italy","Malta","Vatican City","San Marino","Spain","Portugal","Andorra","Gibraltar"

# %%
len(Europe_name)
# Out:
# 46

# %%
for j in range(0,46):
  for i in range(0,5717):
    if data["Country"][i]==Europe_name[j]:
      result.append(a[i])

# %%
result
# Out:
# [array(['Norway', 'Sep-22', 'Net Electricity Production', 'Electricity',
#         8649.8995, 'GWh'], dtype=object),
#  array(['Norway', 'Sep-22', 'Net Electricity Production',
#         'Total Combustible Fuels', 164.0986, 'GWh'], dtype=object),
#  array(['Norway', 'Sep-22', 'Net Electricity Production',
#         'Coal, Peat and Manufactured Gases', 25.9944, 'GWh'], dtype=object),
#  array(['Norway', 'Sep-22', 'Net Electricity Production',
#         'Oil and Petroleum Products', 54.1163, 'GWh'], dtype=object),
#  array(['Norway', 'Sep-22', 'Net Electricity Production',
#         'Combustible Renewables', 20.4741, 'GWh'], dtype=object),
#  array(['Norway', 'Sep-22', 'Net Electricity Production',
#         'Other Combustible Non-Renewables', 63.5139, 'GWh'], dtype=object),
#  array(['Norway', 'Sep-22', 'Net Electricity Production', 'Hydro',
#         7429.7407, 'GWh'], dtype=object),
#  array(['Norway', 'Sep-22', 'Net Electricity Production', 'Wind',
# ...

# %%
result_df=pd.DataFrame(result)

# %%
result_df.columns=["Country", "Time", "Balance", "Product", "Value", "Unit"]

# %%
result_df
# Out:
#        Country    Time                     Balance  \
# 0       Norway  Sep-22  Net Electricity Production
# 1       Norway  Sep-22  Net Electricity Production
# 2       Norway  Sep-22  Net Electricity Production
# 3       Norway  Sep-22  Net Electricity Production
# 4       Norway  Sep-22  Net Electricity Production
# ...        ...     ...                         ...
# 3012  Portugal  Jan-22  Net Electricity Production
# 3013  Portugal  Jan-22  Net Electricity Production
# 3014  Portugal  Jan-22  Net Electricity Production
# 3015  Portugal  Jan-22  Net Electricity Production
# 3016  Portugal  Jan-22  Net Electricity Production
#
#                                          Product      Value Units
# 0                                    Electricity  8649.8995   GWh
# 1                        Total Combustible Fuels   164.0986   GWh
# 2              Coal, Peat and Manufactured Gases    25.9944   GWh
# 3                     Oil and Petroleum Products    54.1163   GWh
# ...

# %%
from google.colab import files

# %%
result_df.to_csv("data111.csv")
files.download("data111.csv")
